# %%
import pandas as pd
from os import listdir

# %%
directory = "ados_datasets_all/"

# %% [markdown]
# #### Preprocessing
# - We don't need the identifiers of the collectinos / patients to do the prediction
# - Keep only the features that can have predictive power
# - Remove all rows with NaNs
# - Update the values, in accordance with: http://www.beginningwitha.com/downloads/ADOS-2%20Presentation.pdf
# - Make the diagnosis a categorical data:
#     - 1 for all patients on the specturm
#     - 0 otherwise
#
# #### Predicting
# - Compare different algorithms
# - K-fold cross validation (K=5) - at least

# %%
filename='current_data.txt'
txtname = directory+filename
data = pd.read_csv(txtname, sep="\t")

# %%
potentiallyUseful = ['age in months at the time of the interview/test/sampling/imaging.',
        'anxiety',
        'hand and finger and other complex mannerisms',
        'imagination/creativity', 
        'immediate echolalia',
        'quality of social overtures', 
        'self-injurious behavior',
        'sex of the subject', 
        'shared enjoyment in interaction',
        'tantrums, aggression, negative or disruptive behavior',
        'unusual eye contact',
        'diagnosis']

# %%
# Remove the rows with NaN values

print ('Number of rows with at least 1 NaN features')
print (data[data.isnull().sum(axis=1) > 0].shape[0])
data = data[data.isnull().sum(axis=1) == 0]
print (str(data.shape[0]) + ' rows left')
# Out:
# Number of rows with at least 1 NaN features
# 5959
# 15892 rows left

# %%
# remove the rows with unknown (9.) variables
# and make the 8. (not applicable) 0 (typical)
# and make the 3. (severe) 2 (not that severe)

for col in potentiallyUseful[2:]:
    data = data[data[col] != 9]
    data[col] = data[col].apply(lambda x: 0 if x == 8 else x)
    data[col] = data[col].apply(lambda x: 2 if x == 3 else x)   
print (str(data.shape[0]) + ' rows left')
# Out:
# 14401 rows left

# %%
# Make the diagnosis column categorical

data['diagnosis'] = pd.to_numeric(data['diagnosis'][data['diagnosis'].apply(lambda x: x.isnumeric())]).apply(lambda x: 1 if x == 2 else x)
data['diagnosis'][(data['diagnosis']!=1) & (data['diagnosis']!=0)]=-1
data= data[data.diagnosis >= 0]
# Out:
# /anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.

# %%
# Create a isMale column

data['isMale'] = data['sex of the subject'].apply(lambda x: 1 if x == 'M' else 0) 
potentiallyUseful.remove('sex of the subject')
potentiallyUseful.append('isMale')

# %%
for col in data[potentiallyUseful]:
    print("COLUMN:", col)
    print(data[col].value_counts())
# Out:
# COLUMN: age in months at the time of the interview/test/sampling/imaging.
# 36.0     469
# 24.0     368
# 37.0     284
# 25.0     256
# 38.0     188
# 84.0     130
# 110.0    125
# 72.0     125
# 40.0     117
# 96.0     114
# 34.0     113
# 60.0     109
# 48.0     108
# 41.0     106
# 126.0    103
# 26.0     102
# 39.0     100
# 50.0      99
# 49.0      96
# 42.0      93
# 35.0      92
# 103.0     91
# 33.0      89
# 108.0     89
# 75.0      88
# 99.0      86
# 83.0      85
# 94.0      85
# 98.0      84
# 134.0     84
#         ...
# 475.0      1
# 357.0      1
# 393.0      1
# 340.0      1
# 470.0      1
# 579.0      1
# 257.0      1
# 490.0      1
# 481.0      1
# 365.0      1
# 540.0      1
# 370.0      1
# 263.0      1
# 378.0      1
# 267.0      1
# 516.0      1
# 349.0      1
# 576.0      1
# 304.0      1
# 412.0      1
# 426.0      1
# 346.0      1
# 308.0      1
# 510.0      1
# 433.0      1
# 456.0      1
# 499.0      1
# 374.0      1
# 301.0      1
# 258.0      1
# Name: age in months at the time of the interview/test/sampling/imaging., Length: 439, dtype: int64
# COLUMN: anxiety
# 0.0    9987
# 1.0    2142
# 2.0     331
# 9.0       1
# Name: anxiety, dtype: int64
# COLUMN: hand and finger and other complex mannerisms
# 0.0    7538
# 2.0    3263
# 1.0    1660
# Name: hand and finger and other complex mannerisms, dtype: int64
# COLUMN: imagination/creativity
# 1.0    4903
# 0.0    4019
# 2.0    3539
# Name: imagination/creativity, dtype: int64
# COLUMN: immediate echolalia
# 0.0    9121
# 1.0    2241
# 2.0    1099
# Name: immediate echolalia, dtype: int64
# COLUMN: quality of social overtures
# 1.0    5823
# 2.0    3840
# 0.0    2798
# Name: quality of social overtures, dtype: int64
# COLUMN: self-injurious behavior
# 0.0    11792
# 1.0      455
# 2.0      214
# Name: self-injurious behavior, dtype: int64
# COLUMN: shared enjoyment in interaction
# 0.0    5868
# 1.0    4469
# 2.0    2124
# Name: shared enjoyment in interaction, dtype: int64
# COLUMN: tantrums, aggression, negative or disruptive behavior
# 0.0    9766
# 1.0    1900
# 2.0     795
# Name: tantrums, aggression, negative or disruptive behavior, dtype: int64
# COLUMN: unusual eye contact
# 2.0    8695
# 0.0    3765
# 1.0       1
# Name: unusual eye contact, dtype: int64
# COLUMN: diagnosis
# 1.0    8578
# 0.0    3883
# Name: diagnosis, dtype: int64
# COLUMN: isMale
# 1    9546
# 0    2915
# Name: isMale, dtype: int64

# %%
def update_columns_labels(data, new_columns):
    updated_data = data.rename(index=str, columns=new_columns)
    return updated_data

# %%
new_columns = {
    "age in months at the time of the interview/test/sampling/imaging.": "age_months",
    "anxiety": "anxiety",
    "hand and finger and other complex mannerisms": "hand_finger_mannerisms",
    "imagination/creativity": "imagination_creativity",
    "immediate echolalia": "immediate_echolalia",
    "quality of social overtures": "quality_social_overtures",
    "self-injurious behavior": "self_injurious_behavior",
    "shared enjoyment in interaction": "shared_enjoyment_interaction",
    "tantrums, aggression, negative or disruptive behavior": "tantrums_aggression_disruptive_behavior",
    "unusual eye contact": "unusual_eye_contact",
    "diagnosis": "diagnosis",
    "isMale": "is_male"
}
update_columns_labels(data[potentiallyUseful], new_columns).to_csv('ados_datasets_all/data.csv', sep=';', index=False)

# %%
data[potentiallyUseful].corr()
# Out:
#                                                     age in months at the time of the interview/test/sampling/imaging.  \
# age in months at the time of the interview/test...                                           1.000000
# anxiety                                                                                      0.067794
# hand and finger and other complex mannerisms                                                -0.154159
# imagination/creativity                                                                      -0.115431
# immediate echolalia                                                                         -0.201017
# quality of social overtures                                                                  0.026853
# self-injurious behavior                                                                     -0.034192
# shared enjoyment in interaction                                                              0.099650
# tantrums, aggression, negative or disruptive be...                                          -0.236583
# unusual eye contact                                                                          0.053761
# diagnosis                                                                                    0.169492
# isMale                                                                                       0.049366
#
#                                                      anxiety  \
# age in months at the time of the interview/test...  0.067794
# anxiety                                             1.000000
# hand and finger and other complex mannerisms        0.004422
# imagination/creativity                              0.096542
# immediate echolalia                                 0.029169
# quality of social overtures                         0.056730
# self-injurious behavior                             0.039161
# shared enjoyment in interaction                     0.075850
# tantrums, aggression, negative or disruptive be...  0.090023
# unusual eye contact                                 0.027491
# diagnosis                                           0.065079
# isMale                                             -0.009394
#
#                                                     hand and finger and other complex mannerisms  \
# age in months at the time of the interview/test...                                     -0.154159
# anxiety                                                                                 0.004422
# hand and finger and other complex mannerisms                                            1.000000
# imagination/creativity                                                                  0.308297
# immediate echolalia                                                                     0.199849
# quality of social overtures                                                             0.367977
# self-injurious behavior                                                                 0.157873
# shared enjoyment in interaction                                                         0.198913
# tantrums, aggression, negative or disruptive be...                                      0.149204
# unusual eye contact                                                                     0.280814
# diagnosis                                                                               0.195564
# isMale                                                                                  0.055404
#
#                                                     imagination/creativity  \
# age in months at the time of the interview/test...               -0.115431
# anxiety                                                           0.096542
# hand and finger and other complex mannerisms                      0.308297
# imagination/creativity                                            1.000000
# immediate echolalia                                               0.171202
# quality of social overtures                                       0.523083
# self-injurious behavior                                           0.150266
# shared enjoyment in interaction                                   0.378542
# tantrums, aggression, negative or disruptive be...                0.264931
# unusual eye contact                                               0.319486
# diagnosis                                                         0.250249
# isMale                                                            0.123735
#
#                                                     immediate echolalia  \
# age in months at the time of the interview/test...            -0.201017
# anxiety                                                        0.029169
# hand and finger and other complex mannerisms                   0.199849
# imagination/creativity                                         0.171202
# immediate echolalia                                            1.000000
# quality of social overtures                                    0.202054
# self-injurious behavior                                        0.043963
# shared enjoyment in interaction                                0.036783
# tantrums, aggression, negative or disruptive be...             0.144207
# unusual eye contact                                            0.165556
# diagnosis                                                      0.108605
# isMale                                                         0.024230
#
#                                                     quality of social overtures  \
# age in months at the time of the interview/test...                     0.026853
# anxiety                                                                0.056730
# hand and finger and other complex mannerisms                           0.367977
# imagination/creativity                                                 0.523083
# immediate echolalia                                                    0.202054
# quality of social overtures                                            1.000000
# self-injurious behavior                                                0.163706
# shared enjoyment in interaction                                        0.524976
# tantrums, aggression, negative or disruptive be...                     0.275487
# unusual eye contact                                                    0.581358
# diagnosis                                                              0.513961
# isMale                                                                 0.137200
#
#                                                     self-injurious behavior  \
# age in months at the time of the interview/test...                -0.034192
# anxiety                                                            0.039161
# hand and finger and other complex mannerisms                       0.157873
# imagination/creativity                                             0.150266
# immediate echolalia                                                0.043963
# quality of social overtures                                        0.163706
# self-injurious behavior                                            1.000000
# shared enjoyment in interaction                                    0.105979
# tantrums, aggression, negative or disruptive be...                 0.220799
# unusual eye contact                                                0.113647
# diagnosis                                                          0.064132
# isMale                                                             0.032677
#
#                                                     shared enjoyment in interaction  \
# age in months at the time of the interview/test...                         0.099650
# anxiety                                                                    0.075850
# hand and finger and other complex mannerisms                               0.198913
# imagination/creativity                                                     0.378542
# immediate echolalia                                                        0.036783
# quality of social overtures                                                0.524976
# self-injurious behavior                                                    0.105979
# shared enjoyment in interaction                                            1.000000
# tantrums, aggression, negative or disruptive be...                         0.182298
# unusual eye contact                                                        0.383890
# diagnosis                                                                  0.317042
# isMale                                                                     0.116489
#
#                                                     tantrums, aggression, negative or disruptive behavior  \
# age in months at the time of the interview/test...                                          -0.236583
# anxiety                                                                                      0.090023
# hand and finger and other complex mannerisms                                                 0.149204
# imagination/creativity                                                                       0.264931
# immediate echolalia                                                                          0.144207
# quality of social overtures                                                                  0.275487
# self-injurious behavior                                                                      0.220799
# shared enjoyment in interaction                                                              0.182298
# tantrums, aggression, negative or disruptive be...                                           1.000000
# unusual eye contact                                                                          0.143344
# diagnosis                                                                                    0.098603
# isMale                                                                                       0.058946
#
#                                                     unusual eye contact  \
# age in months at the time of the interview/test...             0.053761
# anxiety                                                        0.027491
# hand and finger and other complex mannerisms                   0.280814
# imagination/creativity                                         0.319486
# immediate echolalia                                            0.165556
# quality of social overtures                                    0.581358
# self-injurious behavior                                        0.113647
# shared enjoyment in interaction                                0.383890
# tantrums, aggression, negative or disruptive be...             0.143344
# unusual eye contact                                            1.000000
# diagnosis                                                      0.532292
# isMale                                                         0.141249
#
#                                                     diagnosis    isMale
# age in months at the time of the interview/test...   0.169492  0.049366
# anxiety                                              0.065079 -0.009394
# hand and finger and other complex mannerisms         0.195564  0.055404
# imagination/creativity                               0.250249  0.123735
# immediate echolalia                                  0.108605  0.024230
# quality of social overtures                          0.513961  0.137200
# self-injurious behavior                              0.064132  0.032677
# shared enjoyment in interaction                      0.317042  0.116489
# tantrums, aggression, negative or disruptive be...   0.098603  0.058946
# unusual eye contact                                  0.532292  0.141249
# diagnosis                                            1.000000  0.139020
# isMale                                               0.139020  1.000000

# %%
data[data['age in months at the time of the interview/test/sampling/imaging.']<=24].count()
# Out:
# ados diagnosis classification                                                                      575
# age in months at the time of the interview/test/sampling/imaging.                                  575
# anxiety                                                                                            575
# collection_id                                                                                      575
# collection_title                                                                                   575
# dataset_id                                                                                         575
# date on which the interview/genetic test/sampling/imaging/biospecimen was completed. mm/dd/yyyy    575
# hand and finger and other complex mannerisms                                                       575
# imagination/creativity                                                                             575
# immediate echolalia                                                                                575
# overall ados diagnosis                                                                             575
# promoted_subjectkey                                                                                575
# quality of social overtures                                                                        575
# self-injurious behavior                                                                            575
# sex of the subject                                                                                 575
# shared enjoyment in interaction                                                                    575
# stereotyped/idiosyncratic use of words or phrases                                                  575
# subject id how it's defined in lab/project                                                         575
# tantrums, aggression, negative or disruptive behavior                                              575
# the ndar global unique identifier (guid) for research subject                                      575
# unusual eye contact                                                                                575
# diagnosis                                                                                          575
# isMale                                                                                             575
# dtype: int64

# %%
data.columns
# Out:
# Index(['ados diagnosis classification',
#        'age in months at the time of the interview/test/sampling/imaging.',
#        'anxiety', 'collection_id', 'collection_title', 'dataset_id',
#        'date on which the interview/genetic test/sampling/imaging/biospecimen was completed. mm/dd/yyyy',
#        'hand and finger and other complex mannerisms',
#        'imagination/creativity', 'immediate echolalia',
#        'overall ados diagnosis', 'promoted_subjectkey',
#        'quality of social overtures', 'self-injurious behavior',
#        'sex of the subject', 'shared enjoyment in interaction',
#        'stereotyped/idiosyncratic use of words or phrases',
#        'subject id how it's defined in lab/project',
#        'tantrums, aggression, negative or disruptive behavior',
#        'the ndar global unique identifier (guid) for research subject',
#        'unusual eye contact', 'diagnosis', 'isMale'],
#       dtype='object')
